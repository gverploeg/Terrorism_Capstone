# %%
import pandas as pd
import numpy as np
import seaborn as sns

# Read csv file into a pandas dataframe
df = pd.read_csv('../data/globalterrorism.csv', encoding='latin-1')


# pd.read_csv('globalterrorism.csv', sep='|', names=m_cols , encoding='latin-1')
#  Kept receiving this error: 'utf-8' codec can't decode byte 0xe9 in position 18:

# Take a look at the first few rows
df.head()
# df.shape
# Out:
# /opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# ...

# %%
df2 = pd.read_csv('../data/gtd1993.csv', encoding='latin-1')
df2.rename(columns={'ï»¿eventid': 'eventid'}, inplace=True)
df2.shape
df2.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  199301010001   1993       1     1        NaN         0        NaN      603
# 1  199301010002   1993       1     1        NaN         0        NaN       60
# 2  199301030001   1993       1     3        NaN         0        NaN      186
# 3  199301030002   1993       1     3        NaN         0        NaN       97
# 4  199301030003   1993       1     3        NaN         0        NaN       97
#
#       country_txt  region  ...  \
# 0  United Kingdom       8  ...
# 1           Egypt      10  ...
# 2       Sri Lanka       6  ...
# 3          Israel      10  ...
# 4          Israel      10  ...
#
#                                             addnotes  \
# 0  The Red Hand Commandos are a Northern Irish Lo...
# 1                                                NaN
# 2  The soldiers represented the first victims of ...
# 3  Haim Nahmani had arranged to meet a HAMAS info...
# ...

# %%
pwd
# Out:
# '/home/jovyan/work/Desktop/Terrorism_Capstone/notebooks'

# %%
df_ = pd.concat([df, df2], axis=0)


df_.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df_.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.824390e+05  182439.000000  182439.000000  182439.000000
# mean   2.002666e+11    2002.599477       6.468414      15.503571
# std    1.324668e+09      13.246548       3.388535       8.813776
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991022e+11    1991.000000       4.000000       8.000000
# 50%    2.009012e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  182439.000000  182439.000000  182439.000000  177136.000000
# mean        0.045429     132.247222       7.162016      23.498423
# std         0.208243     112.947084       2.933236      18.569221
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
df_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 182439 entries, 0 to 747
# Columns: 135 entries, eventid to related
# dtypes: float64(56), int64(21), object(58)
# memory usage: 189.3+ MB

# %%
# Check for Null values

df_.isnull().sum(axis = 0)
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    173193
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       157401
# Length: 135, dtype: int64

# %%
df_.isnull().sum().sort_values(ascending = False).tail(60)
# Out:
# scite2              105080
# ransom              104968
# nperps               71660
# nperpcap             69747
# nwoundte             69223
# weapdetail           68256
# nkillter             67009
# scite1               66191
# summary              66129
# claimed              66120
# nwoundus             64763
# nkillus              64482
# corp1                42581
# weapsubtype1_txt     20838
# weapsubtype1         20838
# nwound               16352
# targsubtype1_txt     11120
# targsubtype1         11120
# nkill                10329
# longitude             5304
# latitude              5303
# natlty1_txt           1574
# natlty1               1574
# specificity            753
# target1                636
# city                   434
# provstate              421
# guncertain1            380
# ishostkid              178
# multiple                 1
# success                  1
# doubtterr                1
# iyear                    0
# INT_MISC                 0
# ...

# %%
df_.isnull().sum().sort_values(ascending = False).head(50)
# Out:
# gsubname3           182419
# weapsubtype4_txt    182369
# weapsubtype4        182369
# weaptype4           182366
# weaptype4_txt       182366
# claimmode3          182304
# claimmode3_txt      182304
# gsubname2           182279
# claim3              182119
# guncertain3         182117
# gname3              182113
# divert              182107
# attacktype3         182009
# attacktype3_txt     182009
# ransomnote          181922
# ransompaidus        181882
# ransomamtus         181872
# claimmode2          181812
# claimmode2_txt      181812
# ransompaid          181659
# corp3               181400
# targsubtype3        181342
# targsubtype3_txt    181342
# natlty3             181280
# natlty3_txt         181280
# target3             181250
# targtype3_txt       181249
# targtype3           181249
# ransomamt           181083
# weapsubtype3        180736
# weapsubtype3_txt    180736
# weaptype3_txt       180566
# weaptype3           180566
# claim2              180534
# ...

# %%
#  Can see which columns contain a large amount of missing info and the ones that are mostly complete. 
# Determine the columns that are most important for my data exploration.

# %%
print(df_.columns)
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
# New df with specific and renamed columns

df_.rename(columns={'eventid': 'Event_ID', 'iyear': 'Year', 'imonth': 'Month', 'iday': 'Day', 'country_txt':'Country','region_txt':'Region', 'latitude': 'Latitude', 'longitude': 'Longitude', 'attacktype1_txt':'AttackType','target1':'Target','nkill':'Fatalities','nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_Type','weaptype1_txt':'Weapon_Type','motive':'Motive'}, inplace=True)
print(df.columns)
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
terror = df_[['Event_ID', 'Year', 'Month', 'Day', 'Country', 'Region', 'Latitude', 'Longitude', 'AttackType', 'Target', 'Fatalities', 'Wounded', 'Summary', 'Group', 'Target_Type', 'Weapon_Type', 'Motive']]

terror.head()
# Out:
#        Event_ID  Year  Month  Day             Country  \
# 0  197000000001  1970      7    2  Dominican Republic
# 1  197000000002  1970      0    0              Mexico
# 2  197001000001  1970      1    0         Philippines
# 3  197001000002  1970      1    0              Greece
# 4  197001000003  1970      1    0               Japan
#
#                         Region   Latitude   Longitude  \
# 0  Central America & Caribbean  18.456792  -69.951164
# 1                North America  19.371887  -99.086624
# 2               Southeast Asia  15.478598  120.599741
# 3               Western Europe  37.997490   23.762728
# 4                    East Asia  33.580412  130.396361
#
#                        AttackType                   Target  Fatalities  \
# 0                   Assassination             Julio Guzman         1.0
# 1     Hostage Taking (Kidnapping)  Nadine Chaval, daughter         0.0
# 2                   Assassination                 Employee         1.0
# ...

# %%
terror.groupby('Year').count()['Event_ID']

# Shows count of Terrorist attacks each year
# Out:
# Year
# 1970      651
# 1971      471
# 1972      568
# 1973      473
# 1974      581
# 1975      740
# 1976      923
# 1977     1319
# 1978     1526
# 1979     2662
# 1980     2662
# 1981     2586
# 1982     2544
# 1983     2870
# 1984     3495
# 1985     2915
# 1986     2860
# 1987     3183
# 1988     3721
# 1989     4324
# 1990     3887
# 1991     4683
# 1992     5071
# 1993      748
# 1994     3456
# 1995     3081
# 1996     3058
# 1997     3197
# 1998      934
# 1999     1395
# 2000     1814
# 2001     1906
# 2002     1333
# 2003     1278
# 2004     1166
# 2005     2017
# 2006     2758
# 2007     3242
# 2008     4805
# 2009     4721
# 2010     4826
# 2011     5076
# 2012     8522
# 2013    12036
# 2014    16903
# 2015    14965
# 2016    13587
# 2017    10900
# Name: Event_ID, dtype: int64

# %%
# terror.groupby('Year')['Event_ID'].count()&(['Fatalities'] >= 1)

# [terror['casualities']<75

terror[terror['Fatalities'] >= 1].groupby('Year')['Event_ID'].count()
# Out:
# Year
# 1970      65
# 1971     109
# 1972     322
# 1973     244
# 1974     240
# 1975     270
# 1976     312
# 1977     248
# 1978     373
# 1979     835
# 1980    1112
# 1981     926
# 1982     827
# 1983    1008
# 1984    1104
# 1985     940
# 1986    1000
# 1987    1164
# 1988    1636
# 1989    1834
# 1990    1564
# 1991    1660
# 1992    2170
# 1993     300
# 1994    1443
# 1995    1390
# 1996    1296
# 1997    1590
# 1998     450
# 1999     570
# 2000     789
# 2001     902
# 2002     702
# 2003     643
# 2004     744
# 2005    1255
# 2006    1625
# 2007    2028
# 2008    2224
# 2009    2169
# 2010    2169
# 2011    2528
# 2012    4423
# 2013    6078
# 2014    8192
# 2015    7645
# 2016    7080
# 2017    5331
# Name: Event_ID, dtype: int64

# %%
cas = terror[terror['Wounded'] >= 1].groupby('Year')['Event_ID'].count().reset_index()
x = change.iloc[:,0]
y = change.iloc[:,1]

cas.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-c94d72ebc2d2> in <module>
#       1 cas = terror[terror['Wounded'] >= 1].groupby('Year')['Event_ID'].count().reset_index()
# ----> 2 x = change.iloc[:,0]
#       3 y = change.iloc[:,1]
#       4
#       5 cas.head()
#
# NameError: name 'change' is not defined

# %%
change = terror[terror['Fatalities'] >= 1].groupby('Year')['Event_ID'].count().reset_index()





import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
fig, ax = plt.subplots(1, figsize=(15,6))
x = change.iloc[:, 0]
y = change.iloc[:,1]
# ax.bar(x, y, color='b')
sns.barplot(x,y,palette='rocket',edgecolor=sns.color_palette('dark',7))
plt.xticks(rotation=90)
ax.set_xlabel("Year", fontsize=14)
ax.set_ylabel("Number of Attacks", fontsize=14)
ax.set_title("Amount of Attacks Over Time", fontsize=16)
plt.figure(dpi=800);



# import numpy as np
# import matplotlib.pyplot as plt
# plt.style.use('ggplot')
# fig, ax = plt.subplots(1, figsize=(10, 6))
# ax.bar(terror['Year'], change, color='b')
# ax.set_xlabel("Year", fontsize=14)
# ax.set_ylabel("Number of Deaths", fontsize=14)
# ax.set_title("Amount of Deaths Over Time", fontsize=16);
# Out:
# /opt/conda/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
deaths = terror[terror['Fatalities'] >= 1].groupby('Year')['Fatalities'].sum().reset_index()
deaths.head()
# Out:
#    Year  Fatalities
# 0  1970       174.0
# 1  1971       173.0
# 2  1972       566.0
# 3  1973       370.0
# 4  1974       539.0

# %%
deaths = terror[terror['Fatalities'] >= 1].groupby('Year')['Fatalities'].sum().reset_index()

# deaths.head()

import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
fig, ax = plt.subplots(1, figsize=(10, 6))
x = deaths.iloc[:, 0]
y = deaths.iloc[:,1]
ax.bar(x, y, color='b')
ax.set_xlabel("Year", fontsize=14)
ax.set_ylabel("Number of Deaths", fontsize=14)
ax.set_title("Amount of Deaths Over Time", fontsize=16);

# %%
deathss = terror.groupby('Fatalities')['Event_ID'].count().reset_index()
deathss.head(50)

# deathsss = terror['Fatalities'].sum()
# deathsss
# Out:
#     Fatalities  Event_ID
# 0          0.0     88581
# 1          1.0     36701
# 2          2.0     14205
# 3          3.0      7757
# 4          4.0      4976
# 5          5.0      3579
# 6          6.0      2559
# 7          7.0      1967
# 8          8.0      1497
# 9          9.0      1058
# 10        10.0      1196
# 11        11.0       835
# 12        12.0       751
# 13        13.0       575
# 14        14.0       487
# 15        15.0       559
# 16        16.0       403
# 17        17.0       317
# 18        18.0       313
# 19        19.0       210
# 20        19.8        16
# 21        20.0       373
# 22        21.0       199
# 23        22.0       175
# 24        23.0       150
# 25        24.0       132
# 26        25.0       215
# 27        26.0       127
# 28        27.0       112
# 29        28.0        84
# 30        29.0        64
# 31        30.0       195
# 32        31.0        76
# 33        32.0        77
# 34        33.0        44
# 35        34.0        58
# ...

# %%
both = terror[terror['Fatalities'] >= 1].groupby('Year')['Fatalities'].sum()['Event_ID'].count().reset_index()

both.head()

# import numpy as np
# import matplotlib.pyplot as plt
# plt.style.use('ggplot')
# fig, ax = plt.subplots(1, figsize=(10, 6))
# x = deaths.iloc[:, 0]
# y = deaths.iloc[:,1]
# y1 = change.iloc[:,1]
# ax.bar(x, y, color='b')
# ax.bar(x, y1, color='r')
# ax.set_xlabel("Year", fontsize=14)
# ax.set_ylabel("Number of Deaths", fontsize=14)
# ax.set_title("Amount of Deaths Over Time", fontsize=16);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Event_ID'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-a9a1eaf2b9d3> in <module>
# ----> 1 both = terror[terror['Fatalities'] >= 1].groupby('Year')['Fatalities'].sum()['Event_ID'].count().reset_index()
#       2
# ...

# %%
countries = terror[terror['Fatalities'] >= 1].groupby('Country')['Fatalities'].sum().to_frame().reset_index().sort_values('Fatalities', ascending=False)[:15]

countries.head(15)
# Out:
#          Country  Fatalities
# 77          Iraq     78591.0
# 0    Afghanistan     39384.0
# 123     Pakistan     23849.0
# 119      Nigeria     22682.0
# 73         India     19865.8
# 154    Sri Lanka     16586.0
# 161        Syria     15229.0
# 31      Colombia     14832.0
# 128         Peru     12901.0
# 48   El Salvador     12053.0
# 2        Algeria     11113.0
# 117    Nicaragua     10601.0
# 147      Somalia     10352.0
# 129  Philippines      9615.0
# 183        Yemen      8776.0

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
fig, ax = plt.subplots(1, figsize=(15, 6))
x = countries.iloc[:, 0]
y = countries.iloc[:,1]
ax.bar(x, y, color='b')
ax.set_xlabel("Country", fontsize=14)
ax.set_ylabel("Number of Deaths", fontsize=14)
ax.set_title("Countries with the most Deaths", fontsize=16);

# %%
mon_deaths = terror[terror['Fatalities'] >= 1].groupby('Month')['Fatalities'].sum().reset_index()

# deaths.head()

import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
fig, ax = plt.subplots(1, figsize=(10, 6))
x = mon_deaths.iloc[:, 0]
y = mon_deaths.iloc[:,1]
ax.bar(x, y, color='b')
ax.set_xlabel("Year", fontsize=14)
xticks = ['', 'January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
# x = np.arange(len(record_counts['genre']))
ax.set_xticks(np.arange(len(xticks)))
ax.set_xticklabels(xticks)
ax.set_ylabel("Number of Deaths", fontsize=14)
ax.set_title("Amount of Deaths By Month", fontsize=16);

# %%
attack_type = terror.AttackType.value_counts().to_frame().reset_index()
attack_type.columns = ['Attack Type', 'Total Attacks']


import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
fig, ax = plt.subplots(1, figsize=(15, 6))
x = attack_type.iloc[:, 0]
y = attack_type.iloc[:,1]
ax.bar(x, y, color='r')
ax.set_xlabel("Type", fontsize=14)
plt.xticks(rotation=45, fontsize=12, horizontalalignment='right')
ax.set_ylabel("Number of Attacks", fontsize=14)
ax.set_title("Attacks by Type", fontsize=16)
fig.tight_layout();

# %%
target_type = terror.Target_Type.value_counts().to_frame().reset_index()[:10]
target_type.columns = ['Target Type', 'Total Attacks']


import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
fig, ax = plt.subplots(1, figsize=(15, 6))
x = target_type.iloc[:, 0]
y = target_type.iloc[:,1]
ax.bar(x, y, color='r')
ax.set_xlabel("Target", fontsize=14)
plt.xticks(rotation=45, fontsize=12, horizontalalignment='right')
ax.set_ylabel("Number of Attacks", fontsize=14)
ax.set_title("Attacks by Target", fontsize=16)
fig.tight_layout();

# %%
players = terror.Group.value_counts().to_frame().reset_index()[:10]
players.columns = ['Group Involved', 'Total Attacks']

import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
fig, ax = plt.subplots(1, figsize=(15, 6))
x = players.iloc[:, 0]
y = players.iloc[:,1]
ax.bar(x, y, color='r')
ax.set_xlabel("Group", fontsize=14)
plt.xticks(rotation=45, fontsize=12, horizontalalignment='right')
ax.set_ylabel("Number of Attacks", fontsize=14)
ax.set_title("Attacks by Group", fontsize=16)
fig.tight_layout();

# %%
import folium
import folium.plugins

m = folium.Map(location=[45.5236, -122.6750])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-28-28876f39d97e> in <module>
# ----> 1 import folium
#       2 import folium.plugins
#       3
#       4 m = folium.Map(location=[45.5236, -122.6750])
#
# ModuleNotFoundError: No module named 'folium'

# %%
_deaths_over_1 = terror[terror['Fatalities'] >= 1].groupby('AttackType')['Fatalities'].sum().reset_index()

import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
fig, ax = plt.subplots(1, figsize=(15, 6))
x = _deaths_over_1.iloc[:, 0]
y = _deaths_over_1.iloc[:,1]
ax.bar(x, y, color='r')
ax.set_xlabel("Group", fontsize=14)
plt.xticks(rotation=45, fontsize=12, horizontalalignment='right')
ax.set_ylabel("Number of Deaths", fontsize=14)
ax.set_title("Attacks by Type", fontsize=16)
fig.tight_layout();

# %%
age_1_2 = terror[(terror['Fatalities'] >= 1) & (terror['Fatalities'] <=2)]

age_3_9 = terror[(terror['Fatalities'] >= 3) & (terror['Fatalities'] <=9)]

age_10_29 = terror[(terror['Fatalities'] >= 10) & (terror['Fatalities'] <=29)]

age_30 = terror[(terror['Fatalities'] >= 30)]

# %%
death_1_2 = age_1_2.groupby('AttackType')['Event_ID'].count().to_frame().reset_index().sort_values('Event_ID', ascending=False)

death_1_2.head()
# Out:
#                     AttackType  Event_ID
# 2            Bombing/Explosion     17177
# 0                Armed Assault     16056
# 1                Assassination     12975
# 6  Hostage Taking (Kidnapping)      2370
# 8                      Unknown      1688

# %%
death_3_9 = age_3_9.groupby('AttackType')['Event_ID'].count().to_frame().reset_index().sort_values('Event_ID', ascending=False)

death_3_9.head()
# Out:
#                     AttackType  Event_ID
# 2            Bombing/Explosion      9982
# 0                Armed Assault      8736
# 1                Assassination      1823
# 8                      Unknown      1719
# 6  Hostage Taking (Kidnapping)       831

# %%
death_10_29 = age_10_29.groupby('AttackType')['Event_ID'].count().to_frame().reset_index()

death_10_29.head()
# Out:
#                        AttackType  Event_ID
# 0                   Armed Assault      3105
# 1                   Assassination       127
# 2               Bombing/Explosion      2872
# 3  Facility/Infrastructure Attack        78
# 4                       Hijacking        11

# %%
death_30.head(8)
# Out:
#                             AttackType  Event_ID
# 0                        Armed Assault       847
# 1                        Assassination         7
# 2                    Bombing/Explosion       745
# 3       Facility/Infrastructure Attack        16
# 4                            Hijacking         9
# 5  Hostage Taking (Barricade Incident)        31
# 6          Hostage Taking (Kidnapping)       115
# 7                      Unarmed Assault         4

# %%
death_30 = age_30.groupby('AttackType')['Event_ID'].count().to_frame().reset_index()

death_30.iloc[index_list,1]
# Out:
# 0    847
# 1      7
# 2    745
# 6    115
# 8    163
# Name: Event_ID, dtype: int64

# %%
# type(y3)
pd.Series(y4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-8ec16535c96e> in <module>
#       1 # type(y3)
# ----> 2 pd.Series(y4)
#
# NameError: name 'y4' is not defined

# %%
attack_type = terror.AttackType.value_counts().to_frame().reset_index()
attack_type.columns = ['Attack Type', 'Total Attacks'][:7]

attack_type_age_1_2 = age_1_2.AttackType.value_counts().to_frame().reset_index()


attack_type_age_3_9 = age_3_9.AttackType.value_counts().to_frame().reset_index()



import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
fig, ax = plt.subplots(1, figsize=(15, 8))
bar_width = 0.2
index_list = [0,1,2,6,8]
x1 = death_1_2.iloc[:, 0]
x2 = death_3_9.iloc[:,0]
x3 = death_10_29.index
x4 = death_30.index
y1 = death_1_2.iloc[:,1]
y2 = death_3_9.iloc[:,1]
y3 = death_10_29.iloc[:,1]
y4 = death_30.iloc[:,1]
ax.bar(x1, y1, color='tomato', width=bar_width, align='edge', label='1-2 Deaths')
ax.bar(x2, y2, color='royalblue', width=-bar_width, align='edge', label='3-9 Deaths')
ax.bar(x3+.2, y3, color='green', width=bar_width, align='edge', label='10-29 Deaths')
ax.bar(x4-.2, y4, color='gold', width=-bar_width, align='edge', label='>=30 Deaths')
ax.set_xlabel("Type", fontsize=14)
plt.xticks(rotation=45, fontsize=12, horizontalalignment='right')
ax.set_ylabel("Number of Attacks", fontsize=14)
ax.set_title("Attacks by Type", fontsize=16)
# ax.set_ylim(8000,10000)
ax.legend()
fig.tight_layout();

# %%
target_1_2 = age_1_2.groupby('Target_Type')['Event_ID'].count().to_frame().reset_index()

target_3_9 = age_3_9.groupby('Target_Type')['Event_ID'].count().to_frame().reset_index()

target_10_29 = age_10_29.groupby('Target_Type')['Event_ID'].count().to_frame().reset_index()

target_30 = age_30.groupby('Target_Type')['Event_ID'].count().to_frame().reset_index()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
fig, ax = plt.subplots(1, figsize=(15, 8))
bar_width = 0.2
index_list = [0,1,2,6,8]
x1 = target_1_2.iloc[:, 0]
x2 = target_3_9.iloc[:,0]
x3 = target_10_29.index
x4 = target_30.index
y1 = target_1_2.iloc[:,1]
y2 = target_3_9.iloc[:,1]
y3 = target_10_29.iloc[:,1]
y4 = target_30.iloc[:,1]
ax.bar(x1, y1, color='tomato', width=bar_width, align='edge', label='1-2 Deaths')
ax.bar(x2, y2, color='royalblue', width=-bar_width, align='edge', label='3-9 Deaths')
ax.bar(x3+.2, y3, color='green', width=bar_width, align='edge', label='10-29 Deaths')
ax.bar(x4-.2, y4, color='gold', width=-bar_width, align='edge', label='>=30 Deaths')
ax.set_xlabel("Target", fontsize=14)
plt.xticks(rotation=45, fontsize=12, horizontalalignment='right')
ax.set_ylabel("Number of Attacks", fontsize=14)
ax.set_title("Attacks by Target", fontsize=16)
# ax.set_ylim(8000,10000)
ax.legend()
fig.tight_layout();

# %%
region_1_2 = age_1_2.groupby('Region')['Event_ID'].count().to_frame().reset_index()

region_3_9 = age_3_9.groupby('Region')['Event_ID'].count().to_frame().reset_index()

region_10_29 = age_10_29.groupby('Region')['Event_ID'].count().to_frame().reset_index()

region_30 = age_30.groupby('Region')['Event_ID'].count().to_frame().reset_index()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
fig, ax = plt.subplots(1, figsize=(15, 8))
bar_width = 0.2
index_list = [0,1,2,6,8]
x1 = region_1_2.iloc[:, 0]
x2 = region_3_9.iloc[:,0]
x3 = region_10_29.index
x4 = region_30.index
y1 = region_1_2.iloc[:,1]
y2 = region_3_9.iloc[:,1]
y3 = region_10_29.iloc[:,1]
y4 = region_30.iloc[:,1]
ax.bar(x1, y1, color='tomato', width=bar_width, align='edge', label='1-2 Deaths')
ax.bar(x2, y2, color='royalblue', width=-bar_width, align='edge', label='3-9 Deaths')
ax.bar(x3+.2, y3, color='green', width=bar_width, align='edge', label='10-29 Deaths')
ax.bar(x4-.2, y4, color='gold', width=-bar_width, align='edge', label='>=30 Deaths')
ax.set_xlabel("Target", fontsize=14)
plt.xticks(rotation=45, fontsize=12, horizontalalignment='right')
ax.set_ylabel("Number of Deaths", fontsize=14)
ax.set_title("Attacks by Target", fontsize=16)
# ax.set_ylim(8000,10000)
ax.legend()
fig.tight_layout();

# %%
age_1__2 = terror[(terror['Fatalities'] >= 1) & (terror['Fatalities'] <=2)]

age_3_15 = terror[(terror['Fatalities'] >= 3) & (terror['Fatalities'] <=15)]

age_16 = terror[(terror['Fatalities'] >= 16)]

# %%
type_ = terror[terror['Fatalities'] >= 1].groupby('AttackType')['Fatalities'].sum().reset_index().sort_values('Fatalities', ascending=False)[:15]





import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
fig, ax = plt.subplots(1, figsize=(15,6))
x = type_.iloc[:, 0]
y = type_.iloc[:,1]
# ax.bar(x, y, color='b')
sns.barplot(x,y,color="darkmagenta")
plt.xticks(rotation=45, fontsize=12, horizontalalignment='right')
ax.set_xlabel("Type", fontsize=14)
ax.set_ylabel("Number of Deaths", fontsize=14)
ax.set_title("Distribution of Deaths by Type", fontsize=16)
plt.figure(dpi=800);
# Out:
# /opt/conda/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
type_1_2 = age_1__2.groupby('AttackType')['Event_ID'].count().to_frame().reset_index()

type_3_15 = age_3_15.groupby('AttackType')['Event_ID'].count().to_frame().reset_index()

type_16 = age_16.groupby('AttackType')['Event_ID'].count().to_frame().reset_index()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
fig, ax = plt.subplots(1, figsize=(15, 8))
bar_width = 0.2
index_list = [0,1,2,6,8]
x1 = type_3_15.iloc[:, 0]
x2 = type_1_2.iloc[:,0]
x3 = type_16.index
y1 = type_3_15.iloc[:,1]
y2 = type_1_2.iloc[:,1]
y3 = type_16.iloc[:,1]
ax.bar(x2, y2, color='royalblue', width=-bar_width, align='edge', label='1-2 Deaths')
ax.bar(x1, y1, color='tomato', width=bar_width, align='edge', label='3-15 Deaths')
ax.bar(x3+.2, y3, color='gold', width=bar_width, align='edge', label='>=16 Deaths')

ax.set_xlabel("Type", fontsize=14)
plt.xticks(rotation=45, fontsize=12, horizontalalignment='right')
ax.set_ylabel("Number of Attacks", fontsize=14)
ax.set_title("Attacks by Type", fontsize=16)
# ax.set_ylim(8000,10000)
ax.legend()
fig.tight_layout();

# %%
type_1_2_ = age_1__2.groupby('AttackType')['Event_ID'].count().to_frame().drop(type_drops).reset_index().sort_values('Event_ID', ascending=False)
type_1_2_.head()
# Out:
#                     AttackType  Event_ID
# 2            Bombing/Explosion     17177
# 0                Armed Assault     16056
# 1                Assassination     12975
# 3  Hostage Taking (Kidnapping)      2370
# 4                      Unknown      1688

# %%
type_1_2['Order'] = [2,3,1,4,5]


type_1_2.sort_values('Order')
# Out:
#                     AttackType  Event_ID  Order
# 2            Bombing/Explosion     17177      1
# 0                Armed Assault     16056      2
# 1                Assassination     12975      3
# 3  Hostage Taking (Kidnapping)      2370      4
# 4                      Unknown      1688      5

# %%
type_3_15['Order'] = [2,3,1,4,5]

type_3_15.sort_values('Order')
# Out:
#                     AttackType  Event_ID  Order
# 2            Bombing/Explosion     11719      1
# 0                Armed Assault     10646      2
# 1                Assassination      1911      3
# 3  Hostage Taking (Kidnapping)       983      4
# 4                      Unknown      2159      5

# %%
type_16
# Out:
#                     AttackType  Event_ID  Order
# 0                Armed Assault      2042      2
# 1                Assassination        46      3
# 2            Bombing/Explosion      1880      1
# 3  Hostage Taking (Kidnapping)       248      4
# 4                      Unknown       474      5

# %%
type_drops = ['Unarmed Assault', 'Hostage Taking (Barricade Incident)', 'Hijacking', 'Facility/Infrastructure Attack']

type_1_2 = age_1__2.groupby('AttackType')['Event_ID'].count().to_frame().drop(type_drops).reset_index()
type_1_2['Order'] = [2,3,1,4,5]
type_1_2 = type_1_2.sort_values('Order')

type_3_15 = age_3_15.groupby('AttackType')['Event_ID'].count().to_frame().drop(type_drops).reset_index()
type_3_15['Order'] = [2,3,1,4,5]
type_3_15 =type_3_15.sort_values('Order')

type_16 = age_16.groupby('AttackType')['Event_ID'].count().to_frame().drop(type_drops).reset_index()
type_16['Order'] = [2,3,1,4,5]
type_16 = type_16.sort_values('Order')

import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
fig, ax = plt.subplots(1, figsize=(15, 8))
bar_width = 0.2
x1 = type_3_15.iloc[:, 0]
x2 = type_1_2.iloc[:,0]
x3 = type_16.index
y1 = type_3_15.iloc[:,1]
y2 = type_1_2.iloc[:,1]
y3 = type_16.iloc[:,1]
ax.bar(x2, y2, color='royalblue', width=-bar_width, align='edge', label='1-2 Deaths')
ax.bar(x1, y1, color='tomato', width=bar_width, align='edge', label='3-15 Deaths')
ax.bar(x3+.2, y3, color='gold', width=bar_width, align='edge', label='>=16 Deaths')

ax.set_xlabel("Type", fontsize=14)
plt.xticks(rotation=45, fontsize=12, horizontalalignment='center')
ax.set_ylabel("Number of Attacks", fontsize=14)
ax.set_title("Attacks by Type", fontsize=16)
# ax.set_ylim(8000,10000)
ax.legend()
fig.tight_layout();

# %%
target_ = terror[terror['Fatalities'] >= 1].groupby('Target_Type')['Fatalities'].sum().reset_index().sort_values('Fatalities', ascending=False)[:15]





import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
fig, ax = plt.subplots(1, figsize=(15,6))
x = target_.iloc[:, 0]
y = target_.iloc[:,1]
# ax.bar(x, y, color='b')
sns.barplot(x,y,palette='rocket',edgecolor=sns.color_palette('dark',7))
plt.xticks(rotation=45, fontsize=12, horizontalalignment='right')
ax.set_xlabel("Target", fontsize=14)
ax.set_ylabel("Number of Deaths", fontsize=14)
ax.set_title("Distribution of Deaths by Target", fontsize=16)
plt.figure(dpi=800);
# Out:
# /opt/conda/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
target_1_2 = age_1__2.groupby('Target_Type')['Event_ID'].count().to_frame().reset_index()

target_3_15 = age_3_15.groupby('Target_Type')['Event_ID'].count().to_frame().reset_index()

target_16 = age_16.groupby('Target_Type')['Event_ID'].count().to_frame().reset_index()

import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
fig, ax = plt.subplots(1, figsize=(15, 8))
bar_width = 0.2
index_list = [0,1,2,6,8]
x1 = target_3_15.iloc[:, 0]
x2 = target_1_2.iloc[:,0]
x3 = target_16.index
y1 = target_3_15.iloc[:,1]
y2 = target_1_2.iloc[:,1]
y3 = target_16.iloc[:,1]
ax.bar(x2, y2, color='royalblue', width=-bar_width, align='edge', label='1-2 Deaths')
ax.bar(x1, y1, color='tomato', width=bar_width, align='edge', label='3-15 Deaths')
ax.bar(x3+.2, y3, color='gold', width=bar_width, align='edge', label='>=16 Deaths')

ax.set_xlabel("Target", fontsize=14)
plt.xticks(rotation=45, fontsize=12, horizontalalignment='right')
ax.set_ylabel("Number of Attacks", fontsize=14)
ax.set_title("Attacks by Target", fontsize=16)
# ax.set_ylim(8000,10000)
ax.legend()
fig.tight_layout();

# %%
type_1_2 = age_1__2.groupby('Target_Type')['Event_ID'].count().to_frame().reset_index()
type_1_2.head(25)
# Out:
#                        Target_Type  Event_ID
# 0                 Abortion Related         7
# 1              Airports & Aircraft       121
# 2                         Business      3747
# 3          Educational Institution       956
# 4             Food or Water Supply        27
# 5          Government (Diplomatic)       576
# 6             Government (General)      6912
# 7              Journalists & Media       778
# 8                         Maritime        43
# 9                         Military      8304
# 10                             NGO       255
# 11                           Other        39
# 12                          Police      9183
# 13     Private Citizens & Property     14511
# 14  Religious Figures/Institutions      1230
# 15               Telecommunication        60
# 16    Terrorists/Non-State Militia      1485
# 17                        Tourists       106
# 18                  Transportation       930
# 19                         Unknown       780
# ...

# %%
target_drops = ['Abortion Related','Food or Water Supply', 'Telecommunication', 'Utilities', 'Other', 'Unknown', 'Maritime', 'Violent Political Party', 'NGO', 'Government (Diplomatic)', 'Tourists']
target_drops1 = ['Food or Water Supply', 'Telecommunication', 'Utilities', 'Other', 'Unknown', 'Maritime', 'Violent Political Party', 'NGO', 'Government (Diplomatic)', 'Tourists']

target_1_2 = age_1__2.groupby('Target_Type')['Event_ID'].count().to_frame().drop(target_drops).reset_index()

target_3_15 = age_3_15.groupby('Target_Type')['Event_ID'].count().to_frame().drop(target_drops).reset_index()

target_16 = age_16.groupby('Target_Type')['Event_ID'].count().to_frame().drop(target_drops1).reset_index()


import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
fig, ax = plt.subplots(1, figsize=(15, 8))
bar_width = 0.2
index_list = [0,1,2,6,8]
x1 = target_3_15.iloc[:, 0]
x2 = target_1_2.iloc[:,0]
x3 = target_16.index
y1 = target_3_15.iloc[:,1]
y2 = target_1_2.iloc[:,1]
y3 = target_16.iloc[:,1]
ax.bar(x2, y2, color='royalblue', width=-bar_width, align='edge', label='1-2 Deaths')
ax.bar(x1, y1, color='tomato', width=bar_width, align='edge', label='3-15 Deaths')
ax.bar(x3+.2, y3, color='gold', width=bar_width, align='edge', label='>=16 Deaths')

ax.set_xlabel("Target", fontsize=14)
plt.xticks(rotation=45, fontsize=12, horizontalalignment='center')
ax.set_ylabel("Number of Attacks", fontsize=14)
ax.set_title("Attacks by Target", fontsize=16)
# ax.set_ylim(8000,10000)
ax.legend()
fig.tight_layout();

# %%
regions = terror[terror['Fatalities'] >= 1].groupby('Region')['Fatalities'].sum().reset_index().sort_values('Fatalities', ascending=False)[:15]





import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
fig, ax = plt.subplots(1, figsize=(15,6))
x = regions.iloc[:, 0]
y = regions.iloc[:,1]
# ax.bar(x, y, color='b')
sns.barplot(x,y,palette='rocket',edgecolor=sns.color_palette('dark',7))
plt.xticks(rotation=45, fontsize=12, horizontalalignment='right')
ax.set_xlabel("Regions", fontsize=14)
ax.set_ylabel("Number of Deaths", fontsize=14)
ax.set_title("Regional Distribution of Deaths", fontsize=16)
plt.figure(dpi=800);
# Out:
# /opt/conda/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
type_1_2 = age_1__2.groupby('Region')['Event_ID'].count().to_frame().reset_index()

type_3_15 = age_3_15.groupby('Region')['Event_ID'].count().to_frame().reset_index()

type_16 = age_16.groupby('Region')['Event_ID'].count().to_frame().reset_index()

import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
fig, ax = plt.subplots(1, figsize=(15, 8))
bar_width = 0.2
index_list = [0,1,2,6,8]
x1 = type_3_15.iloc[:, 0]
x2 = type_1_2.iloc[:,0]
x3 = type_16.index
y1 = type_3_15.iloc[:,1]
y2 = type_1_2.iloc[:,1]
y3 = type_16.iloc[:,1]
ax.bar(x2, y2, color='royalblue', width=-bar_width, align='edge', label='1-2 Deaths')
ax.bar(x1, y1, color='tomato', width=bar_width, align='edge', label='3-15 Deaths')
ax.bar(x3+.2, y3, color='gold', width=bar_width, align='edge', label='>=16 Deaths')

ax.set_xlabel("Region", fontsize=14)
plt.xticks(rotation=45, fontsize=12, horizontalalignment='right')
ax.set_ylabel("Number of Attacks", fontsize=14)
ax.set_title("Attacks by Region", fontsize=16)
# ax.set_ylim(8000,10000)
ax.legend()
fig.tight_layout();

# %%
type_3_15 = age_3_15.groupby('Region')['Event_ID'].count().to_frame().reset_index()

# %%
type_3_15 = age_3_15.groupby('Region')['Event_ID'].count().to_frame().reset_index()
type_3_15.head(20)
# Out:
#                          Region  Event_ID
# 0         Australasia & Oceania        13
# 1   Central America & Caribbean      1386
# 2                  Central Asia        72
# 3                     East Asia        58
# 4                Eastern Europe       440
# 5    Middle East & North Africa      9294
# 6                 North America       112
# 7                 South America      2329
# 8                    South Asia      8308
# 9                Southeast Asia      1335
# 10           Sub-Saharan Africa      4154
# 11               Western Europe       295

# %%
list_of_items_frop = ['Australasia & Oceania', 'Central Asia', 'East Asia' ]



type_1_2 = age_1__2.groupby('Region')['Event_ID'].count().to_frame().drop(list_of_items_frop).reset_index()

type_3_15 = age_3_15.groupby('Region')['Event_ID'].count().to_frame().drop(list_of_items_frop).reset_index()

type_16 = age_16.groupby('Region')['Event_ID'].count().to_frame().drop(list_of_items_frop).reset_index()

import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
fig, ax = plt.subplots(1, figsize=(15, 8))
bar_width = 0.2
index_list = [0,1,2,6,8]
x1 = type_3_15.iloc[:, 0]
x2 = type_1_2.iloc[:,0]
x3 = type_16.index
y1 = type_3_15.iloc[:,1]
y2 = type_1_2.iloc[:,1]
y3 = type_16.iloc[:,1]
ax.bar(x2, y2, color='royalblue', width=-bar_width, align='edge', label='1-2 Deaths')
ax.bar(x1, y1, color='tomato', width=bar_width, align='edge', label='3-15 Deaths')
ax.bar(x3+.2, y3, color='gold', width=bar_width, align='edge', label='>=16 Deaths')

ax.set_xlabel("Region", fontsize=14)
plt.xticks(rotation=45, fontsize=12, horizontalalignment='right')
ax.set_ylabel("Number of Attacks", fontsize=14)
ax.set_title("Attacks by Region", fontsize=16)
# ax.set_ylim(8000,10000)
ax.legend()

# %%
attack_type = terror.AttackType.value_counts().to_frame().reset_index()
attack_type.columns = ['Attack Type', 'Total Attacks'][:7]

attack_type_age_1_2 = age_1_2.AttackType.value_counts().to_frame().reset_index()


attack_type_age_3_9 = age_3_9.AttackType.value_counts().to_frame().reset_index()



import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
fig, ax = plt.subplots(1, figsize=(15, 6))
bar_width = 0.2
index_list = [0,1,2,6,8]
y1 = death_1_2.iloc[:, 0]
y2 = death_3_9.iloc[:,0]
y3 = death_10_29.index
y4 = death_30.index
x1 = death_1_2.iloc[:,1]
x2 = death_3_9.iloc[:,1]
x3 = death_10_29.iloc[:,1]
x4 = death_30.iloc[:,1]
ax.bar(x1, y1, color='r', width=bar_width, align='edge')
ax.bar(x2, y2, color='b', width=-bar_width, align='edge')
ax.bar(x3+.2, y3, color='y', width=bar_width, align='edge')
ax.bar(x4-.2, y4, color='orange', width=-bar_width, align='edge')
ax.set_xlabel("Type", fontsize=14)
plt.xticks(rotation=45, fontsize=12, horizontalalignment='right')
ax.set_ylabel("Number of Attacks", fontsize=14)
ax.set_title("Attacks by Type", fontsize=16)
# ax.set_ylim(8000,10000)
fig.tight_layout();

# %%
# plotting
fig, ax = plt.subplots(1, figsize=(15, 6))
ax.scatter(x_blue, y_blue, color="blue")
ax.scatter(x_red, y_red, color="red")

# %%
touch .gitignore
# top folder - ignore data folder

# %%
def grouped_bar_frame(ax, vals, group_names, legend_names, colors, width = .2):
    '''Plots framework for a grouped bar plot (to be fine tuned in the scope above)'''
    ind = np.arange(2)
    arr = np.array(vals)
    ax.bar(ind - width/2, arr[:,0], width, label = legend_names[0], color = colors[0])
    ax.bar(ind + width/2, arr[:,1], width, label = legend_names[1], color = colors[1])
    ax.set_xticks(ind)
    ax.set_xticklabels(group_names)
    ax.legend(prop=dict(size=30))
    
def create_halfs_chart(ax, team_df):
    home, away = team_df[team_df.home],team_df[~team_df.home]
    away_d, home_d = (retrosheet_data_analysis.season_half_win_rates(away),
                    retrosheet_data_analysis.season_half_win_rates(home) )
    grouped_bar_frame(ax, [home_d,away_d], ["Home", "Away"], ["First Half", "Second Half"], colors = ['#13866d', '#ba8f0d'])
    
    ax.set_ylim(0,.6)
    ax.set_yticks(np.arange(0, .6, step=0.125))
    ax.tick_params(axis = 'y', labelsize = 25)
    ax.tick_params(axis = 'x', labelsize = 30)
    ax.set_ylabel("Winrate", size = 30)
    ax.set_title("First Half vs Second Half Winrates", size = 30)

# %%
def BarGraphGrouped(labels,title,xlabel,ylabel,group1,group1_label,group2,group2_label,card_color=None):

    fig = plt.figure(figsize=(12,5))
    ax = fig.add_subplot(111)
    
    save_title = title.replace(' ','_')
    
    barlabels = [x for x in labels]
    bar1 = [y for y in group1]
    bar2 = [z for z in group2]
    width_ = 0.4
    
    if card_color == 'Yellow' or card_color == 'yellow':
        color1, color2, edge = ('palegoldenrod','goldenrod','darkgoldenrod')
    elif card_color == 'Red' or card_color == 'red':
        color1, color2, edge = ('lightcoral','firebrick','maroon')
        
    r1 = np.arange(len(bar1))
    r2 = [x+width_ for x in r1]
    ax.bar(r1,bar1,color=color1,width=width_,edgecolor=edge,label=group1_label)
    ax.bar(r2,bar2,color=color2,width=width_,label=group2_label)

    ax.set_xticks(r1)
    ax.set_xticklabels(barlabels,rotation=45,fontdict={'fontsize':9})
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    plt.legend(loc='best')
    plt.tight_layout()
    plt.savefig(f'/home/josh/Documents/dsi/caps/cap1/images/{save_title}.jpeg',dpi=100)
    plt.show()

avg_games_reffed = df.ref_name.value_counts().mean() # The average number of games reffed is 120 games. There are 24 refs with more than 120 games. 
                                                    #   Any more than that would be too many to graph
sorted_totrefs = totrefs.sort_values('Games_reffed',ascending=False)
top_refs = sorted_totrefs[sorted_totrefs['Games_reffed'] >= avg_games_reffed]

title_yellow_bar = 'Home and Away Yellow Cards for Referees that have Overseen at least 120 Games'
BarGraphGrouped(top_refs.ref_name,title_yellow_bar,'Referees','Number of Cards',top_refs.HY,'Home Yellows',top_refs.AY,'Away Yellows','yellow')

# %%
def plot_bar_year_dual(df_obj, save_on=True):
    '''Create bar plots of mens/womens and mens/womens/mixed events by
    year for the dataframe object with an overlay of the percent womens
    events
    Parameters
    ----------
    df_obj: GenderDataFrames object
        contains DataFrames to plot
    save_on: bool, optional
        if true the plots will be saved, if false the plots will show
        on the screen (default is True)
    Returns
    -------
    None
    '''
    year = df_obj.annual_medals_df.index
    y = df_obj.annual_medals_df['%_womens_events']
    labels = [df_obj.season, 'Events', 'Year']
    y3_a = df_obj.annual_medals_df['mens_events']
    y3_b = df_obj.annual_medals_df['womens_events']
    ax3 = gender_counts_plot(year, y3_a, labels, color='tab:cyan',
                             label='Mens Events')
    ax3_a = gender_counts_plot(year+1, y3_b, labels, ax3, color='tab:pink',
                               label='Womens Events')
    ax3_b = ax3_a.twinx()
    ax3_b = percent_plot(year, y, df_obj.season, ax3_b, color='tab:pink',
                         label='Percent Womens Events')
    ax3_b.annotate('Olympics\ncanceled\ndurring\nWWII', (1938, 6),
                   multialignment='center', fontsize=14)
    if save_on:
        plt.savefig(f'../images/{df_obj.season}/no-mix-count-year-plot.png')
    y = df_obj.annual_medals_mixed_df['%_womens_events']
    y4_a = df_obj.annual_medals_mixed_df['mens_events']
    y4_b = df_obj.annual_medals_mixed_df['womens_events']
    y4_c = df_obj.annual_medals_mixed_df['mixed_events']
    ax4 = gender_counts_plot(year-0.7, y4_a, labels, color='tab:cyan',
                             label='Mens Events', width=0.7)
    ax4 = gender_counts_plot(year, y4_b, labels, ax4, color='tab:pink',
                             label='Womens Events', width=0.7)
    ax4 = gender_counts_plot(year+0.7, y4_c, labels, ax4, color='tab:purple',
                             label='Mixed Events', width=0.7)
    ax4 = percent_plot(year, y, df_obj.season, ax4, color='tab:purple',
                       label='Percent Womens Events')
    if save_on:
        plt.savefig(f'../images/{df_obj.season}/mix-count-year-plot.png')
